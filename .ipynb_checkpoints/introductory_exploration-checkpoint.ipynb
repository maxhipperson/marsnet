# %%
# %matplotlib qt
import hyperspy.api as hs

import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-be5f2e9fc557> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'qt')
#       2 import hyperspy.api as hs
#       3
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# ~/.local/share/virtualenvs/marsnet-ZEfWMKGE/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2285                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2286             with self.builtin_trap:
# -> 2287                 result = fn(*args,**kwargs)
#    2288             return result
#    2289
#
# <decorator-gen-107> in matplotlib(self, line)
#
# ~/.local/share/virtualenvs/marsnet-ZEfWMKGE/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
# ...
